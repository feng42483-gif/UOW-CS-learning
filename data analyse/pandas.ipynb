# %%
from tarfile import data_filter

import  pandas as pd

df = pd.DataFrame([
    {"姓名":"小王","chinese":91,"math":89,"english":91},
    {"姓名":"小李","chinese":95,"math":85,"english":93},
    {"姓名":"小张","chinese":86,"math":84,"english":95},
    {"姓名":"小红","chinese":80,"math":88,"english":90}
])
df
# Out:
#    姓名  chinese  math  english
# 0  小王       91    89       91
# 1  小李       95    85       93
# 2  小张       86    84       95
# 3  小红       80    88       90
